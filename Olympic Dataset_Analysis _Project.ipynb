# %% [markdown]
# # **Project Name - Olympics Data Analysis**

# %% [markdown]
# **Implemented By Pragati Goregaonkar**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The project aims to analyze Olympic data to uncover trends in athlete performance, country competitiveness, medal distribution and gender
# participation using data analysis and visualization techniques.**

# %% [markdown]
# # **Objective**

# %% [markdown]
#  **1)Analyze Country Performance in the Olympics by assessing the medal counts and overall performance of various countries.**
#
#  **2)Medal Distribution Insights by analyzing the distribution of gold, silver, and bronze medals across different countries**
#
#  **3)Analyze or Compare the total number of male and female athletes participating  across countries.**
#
#  **4)Analyze the relationship between a country’s athlete count and its medal achievements to understand the effects of participation on success.**
#
#  **5)Data Visualization by creating compelling visualizations to represent the performance and medal statistics of countries.**
#
#  **6)Use Data-Driven Insights by providing insights that can inform future performance evaluations and sports strategies.**

# %% [markdown]
# # *Understanding Variable*

# %% [markdown]
# **City**	City that hosted the Olympic Games
# **Year**	Year the Olympic Games took place (held every 4yrs)
# **Sport**	Sport Catergory (eg. Aquatics, Atheletics etc.)
# **Discipline**	The discipline within the sport (eg. Diving, Swimming etc.)
# **Event**	Event Name within the particular discipline (eg. 3m springboard, 10m platform etc.)
# **Athlete**	Winners name in that event
# **Gender**	Athletes Gender
# **Country Code**	3 character country code
# **Country**	Country to which the winning athlete represents
# **Event Gender**	Genders which participated in the event (Male, Female or Common Event)
# **Medal**	Medal Awarded(eg. Bronze, Silver, Gold)

# %%
# Installing the Libraries 
# !pip install panda
# !pip install matplotlib
# !pip install numpy

# %% [markdown]
#  **Insight**  Installed all necessary packages

# %% [markdown]
# # *Import necessary packages*

# %%
# Importing the necessary libraries
import pandas as pd  # For data manipulation and analysis
import numpy as np   # For numerical operations
import matplotlib.pyplot as plt  # For creating visualizations
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Insight**   Imported all necessary packages

# %% [markdown]
# # *Load the dataset*

# %%
#Importing the Pandas library
import pandas as pd

# Reading a CSV file 
df = pd.read_csv(r"C:\Users\goreg\OneDrive\Desktop\New folder (4)\Summer-Olympic-medals-1976-to-2008.csv",encoding='latin-1')
df = df.copy()
df
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %% [markdown]
# **Insight:**
# Loading the dataset into a Pandas DataFrame allows for easy manipulation and analysis of the data.

# %%
# Prints the shape i.e. the row size by column size of the dataset
df.shape
# Out:
# (15433, 11)

# %% [markdown]
# **Insight**   Here we print row and column size of the dataset

# %% [markdown]
# # *Dataset View*

# %%
df['Year'] = df['Year'].fillna(0).astype(int)  # Replace NaN with 0

# %%
# Display the top 5 rows of the DataFrame 'df' to quickly inspect the data.
# This helps to verify the structure, column names, and sample data.
df.head()
# Out:
#        City  Year     Sport Discipline           Event  \
# 0  Montreal  1976  Aquatics     Diving  3m springboard
# 1  Montreal  1976  Aquatics     Diving  3m springboard
# 2  Montreal  1976  Aquatics     Diving  3m springboard
# 3  Montreal  1976  Aquatics     Diving  3m springboard
# 4  Montreal  1976  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %% [markdown]
# **Insight**   Here we print first five rows of the dataset.

# %%
# Display the bottom 5 rows of the DataFrame 'df' to inspect the last few entries.
# This helps to check the data at the end of the dataset for completeness or errors.
df.tail()
# Out:
#           City  Year      Sport       Discipline       Event  \
# 15428  Beijing  2008  Wrestling  Wrestling Gre-R   66 - 74kg
# 15429  Beijing  2008  Wrestling  Wrestling Gre-R   66 - 74kg
# 15430  Beijing  2008  Wrestling  Wrestling Gre-R   55 - 60kg
# 15431  Beijing  2008  Wrestling  Wrestling Gre-R   60 - 66kg
# 15432  Beijing  2008  Wrestling  Wrestling Gre-R  96 - 120kg
#
#                    Athlete Gender Country_Code     Country Event_gender  \
# 15428   GUENOT, Christophe    Men          FRA      France            M
# 15429  KVIRKELIA, Manuchar    Men          GEO     Georgia            M
# 15430     RAHIMOV, Vitaliy    Men          AZE  Azerbaijan            M
# 15431       GUENOT, Steeve    Men          FRA      France            M
# 15432        LOPEZ, Mijain    Men          CUB        Cuba            M
#
#         Medal
# 15428  Bronze
# 15429    Gold
# 15430  Silver
# 15431    Gold
# 15432    Gold

# %% [markdown]
# **Insight**    Here we print last five rows of the dataset

# %%
# To print the column names present in the dataset
df.columns
# Out:
# Index(['City', 'Year', 'Sport', 'Discipline', 'Event', 'Athlete', 'Gender',
#        'Country_Code', 'Country', 'Event_gender', 'Medal'],
#       dtype='object')

# %% [markdown]
# **Insight**   Print the column name present in the dataset

# %% [markdown]
# # *Dataset Information*

# %%
# Display a concise summary of the DataFrame 'df', including the number of entries, 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15433 entries, 0 to 15432
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15433 non-null  int64
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  object
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 1.3+ MB

# %% [markdown]
# **Insight**   We use info() to get concise summary of our dataset.

# %% [markdown]
# # *Descriptive Statistics Overview*

# %%
# Statistical measurement of the dataset

df.describe()
# Out:
#                Year
# count  15433.000000
# mean    1978.506836
# std      173.226547
# min        0.000000
# 25%     1984.000000
# 50%     1996.000000
# 75%     2004.000000
# max     2008.000000

# %% [markdown]
# **Insight**
# df.describe() summarizes numeric data, showing metrics like mean and standard deviation.

# %% [markdown]
# # *Cleaning the Data*

# %% [markdown]
# **Missing Values/Null Values**

# %%
# Calculate and display the total number of missing values in each column of 'df'.
df.isnull().sum()
# Out:
# City            117
# Year              0
# Sport           117
# Discipline      117
# Event           117
# Athlete         117
# Gender          117
# Country_Code    117
# Country         117
# Event_gender    117
# Medal           117
# dtype: int64

# %%
df.dropna(inplace=True)
df.shape
# Fill null values instead (optional)
df_filled = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# City            0
# Year            0
# Sport           0
# Discipline      0
# Event           0
# Athlete         0
# Gender          0
# Country_Code    0
# Country         0
# Event_gender    0
# Medal           0
# dtype: int64

# %% [markdown]
# **Insight**
# Here we used isnull().sum() to identify and count missing values (NaNs) in a DataFrame.
#
# All columns in the DataFrame contain complete data with no missing values, ensuring reliable analysis.

# %% [markdown]
#  **Duplicate Values**

# %%
# to check for duplicate rows in a DataFrame
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
#It is used to remove duplicate rows from a DataFrame named
df.drop_duplicates(inplace = True)

# %%
# Prints the shape i.e. the row size by column size of the dataset
df.shape
# Out:
# (15315, 11)

# %% [markdown]
# ## **Visualization No.1**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('dark_background')
sns.countplot(y='City',data=df)
# Out:
# <Axes: xlabel='count', ylabel='City'>

# %% [markdown]
# **Insight**
# Beijing has the maximum number of participants and Montreal has the lowest.

# %% [markdown]
# ## **Visualization No.2**

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
sns.countplot(x='Sport',data=df)
# Out:
# <Axes: xlabel='Sport', ylabel='count'>

# %% [markdown]
# **Insight**
# Aquatics sport had maximum number of participants.

# %% [markdown]
# ## **Visualization No.3**

# %%
plt.figure(figsize=(8,8))
sns.countplot(y='City',hue='Medal',data=df,palette='coolwarm')
# Out:
# <Axes: xlabel='count', ylabel='City'>

# %% [markdown]
# **Insight**
# Beijing has max number of gold medals
# Sydney has max number of silver medals
# Beijing has max number of bronze medals

# %% [markdown]
# ## **Visualization No.4**

# %%
plt.figure(figsize=(8,8))
sns.countplot(y='City',hue='Gender',data=df,palette='Set2')
# Out:
# <Axes: xlabel='count', ylabel='City'>

# %% [markdown]
# **Insight**
# Beijing had max female participation.
# Sydney had max male participation.

# %% [markdown]
# ## **Visualization No.5**

# %%
sns.countplot(x='Year',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %% [markdown]
# **Insight**
# number of participations has been increasing each year but 2004 saw a dip in number of participants.

# %% [markdown]
# ## **Visualization No.6**

# %%
sns.kdeplot(df['Year'])
# Out:
# <Axes: xlabel='Year', ylabel='Density'>

# %% [markdown]
# ## **Visualization No.7**

# %%
plt.figure(figsize=(8,8))
sns.catplot(y='Year',col='Gender',data=df,kind='count')

# %% [markdown]
# **Insight**
#  Women had more number of participations in year 2008.
#  Men had more number of participations in year 2000.

# %% [markdown]
# ## **Visualization No.8**

# %%
sns.kdeplot(y='Year',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Density', ylabel='Year'>

# %% [markdown]
# **Insight**
# compared to women, men had more number of participations.

# %% [markdown]
# ## **Visualization No.9**

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
sns.countplot(x='Sport',data=df,hue='Gender')
# Out:
# <Axes: xlabel='Sport', ylabel='count'>

# %% [markdown]
# **Insight**
# Aquatics sport had max number of both male and female participations.

# %% [markdown]
# ## **Visualization No.10**

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
sns.countplot(x='Sport',data=df,hue='Medal')
# Out:
# <Axes: xlabel='Sport', ylabel='count'>

# %% [markdown]
# **Insight**
# max number of gold,silver and bronze medals are in Aquatics sport.

# %% [markdown]
# ## **Visualization No.11**

# %%
sns.countplot(x='Gender',data=df,palette='coolwarm')
# Out:
# C:\Users\goreg\AppData\Local\Temp\ipykernel_9684\1564635876.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender',data=df,palette='coolwarm')
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ## **Visualization No.12**

# %%
sns.countplot(x='Gender',hue='Medal',data=df,palette='magma')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ## **Visualization No.13**

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
sns.countplot(x='Discipline',data=df,hue='Gender',palette='Set2')
# Out:
# <Axes: xlabel='Discipline', ylabel='count'>

# %% [markdown]
# **Insight**
# Athletics has more number of male participations.
# Swimming has more number of female participations.

# %% [markdown]
# ## **Visualization No.14**

# %%
plt.figure(figsize=(8,24))
plt.xticks(rotation=90)
sns.countplot(y='Country',data=df)
# Out:
# <Axes: xlabel='count', ylabel='Country'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# **We analyzed top-performing countries and athletes based on medal wins, explored gender participation in sports, and visualized medal trends over the years. Using a logistic regression model, we predicted an athlete's likelihood of winning a medal based on factors like country, sport, and gender.**

# %% [markdown]
# # Recommendation

# %% [markdown]
# **Increase Athlete Participation: Countries should send more athletes to improve their chances of winning medals.**
#
# **Promote Gender Equality: Encourage more female athletes to participate to create balanced teams.**
#
# **Invest in Sports: Countries with fewer medals should invest in better training and sports infrastructure.**
#
# **Focus on All Medals: Countries should aim to win across all medal types (gold, silver, bronze), not just one.**
#
# **Use Home Advantage: Host countries should support their athletes more to boost their chances of success.**
#
# **Support Female Athletes: Countries with fewer female participants should provide better support to encourage their participation.**
#
# **Learn from Top Countries: Countries should study how top-performing nations like the U.S. and China succeed and adopt similar strategies.**
#
# **Improve Repeat Participation: Encourage athletes to return in future Olympics to strengthen chances of success.**
#
# **Balance Medal Focus: Don’t just focus on winning gold medals—strong performances in all categories help overall rankings.**
